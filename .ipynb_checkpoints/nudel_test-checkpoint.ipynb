# %%
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline
import matplotlib.pyplot as plt

# import project_path
from nudel import Nuclide

from uncertainties import ufloat

from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

from icecream import ic
# Out:
# <style>.container { width:80% !important; }</style>
# WARNING: The --force flag will be removed in a future conda release.
#          See 'conda install --help' for details about the --force-reinstall
#          and --clobber flags.
#
#
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/anl.gov/jfox/anaconda3/envs/nudat
#
#   added / updated specs:
#     - icecream
#
#
# The following NEW packages will be INSTALLED:
#
#   icecream           conda-forge/noarch::icecream-2.1.3-pyhd8ed1ab_0 None
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 14
#      11 display(HTML("<style>.container { width:80% !important; }</style>"))
#      13 get_ipython().system('conda install -fc conda-forge icecream')
# ---> 14 from icecream import ic
#
# ...

# %% [markdown]
# # Level scheme plots

# %%
def level_scheme(nuc=None, nucleons=None, protons=None, n_max = 40):
    decays = []
    if not nuc:
        nuc = Nuclide(nucleons, protons)
    for level in nuc.adopted_levels.levels[:n_max]:
        decays.extend(level.decays)
    
    i = 0.5
    for level in nuc.adopted_levels.levels[:n_max]:
        plt.axhline(level.energy.val, color='k')
        for decay in level.decays:
            plt.plot(
                [i, i],
                [decay.orig_level.energy.val, decay.dest_level.energy.val],
            )
            i += 1
    plt.xlim(0, i - 0.5)
    plt.ylim(0, nuc.adopted_levels.levels[n_max].energy.val)
    plt.show()
    
# level_scheme(nucleons=20, protons=10, n_max=10)

# %% [markdown]
# # Load transition from ENSDF

# %%
class Gamma():
    """
    container class for Gamma (M1,E2) transitions
    """
    def __init__(self,A,Z,N,multipolarity):
        self.multipolarity = multipolarity
        self.A = A
        self.Z = Z
        self.N = N
        self.nuc = Nuclide(self.A,self.Z)
        
        self.twoJi = None
        self.twoJf = None
        self.ni = None
        self.nf = None
        
        self.Ei = None
        self.Ef = None
        self.dEi = None
        self.dEf = None
        
        self.BW = None
        self.dBW = None
        
#         self.Thalf = None
        self.ref = None
        
        
    def collect_transitions(self,n_max = 40):
        self.decays = []
        for level in self.nuc.adopted_levels.levels[:n_max]:
            self.decays.extend(level.decays)

        self.trans_list = []
        for decay in self.decays:
            print(decay.prop)
            if self.multipolarity in decay.attr.keys():
                self.trans_list.append(decay)
    #             print('Added to the list!')
            
#     def fill(self,decay,twoJi,twoJf,ni,nf):
#         self.twoJi = twoJi
#         self.twoJf = twoJf
#         self.ni = ni
#         self.nf = nf
        
#         self.Ei = decay.orig_level.energy.val
#         self.Ef = decay.dest_level.energy.val
#         self.dEi = decay.orig_level.energy.pm
#         self.dEf = decay.dest_level.energy.pm
            
#         o_string = f'B{multipolarity}W'
#         self.BW = decay.attr[o_string].val
#         self.dBW = decay.attr[o_string].pm
        
# #         self.Thalf = None
#         self.xref = decay.xref

    def fill_levels(self):
        pass
        
    def fill_targets(self,decay,twoJi,twoJf,ni,nf):
        self.twoJi = twoJi
        self.twoJf = twoJf
        self.ni = ni
        self.nf = nf
        
        self.Ei = decay.orig_level.energy.val
        self.Ef = decay.dest_level.energy.val
        self.dEi = decay.orig_level.energy.pm
        self.dEf = decay.dest_level.energy.pm
            
        o_string = f'B{multipolarity}W'
        self.BW = decay.attr[o_string].val
        self.dBW = decay.attr[o_string].pm
        
#         self.Thalf = None
        self.xref = decay.xref

# %%
nuc = Nuclide(23,11)
n_levels = 20
levels = nuc.adopted_levels.levels[:n_levels]
decays = [x.decays for x in levels]
len(decays)
# Out:
# 20

# %%
d = decays[2]
d[1].xref
# Out:
# []

# %%
def clean_levels(levels):
    keep = []
    for l in levels:
        if not len(l.ang_mom)>0:
            continue
        if not l.ang_mom[0].parity=='+':
            continue
        keep.append(l)
    return keep

# %%
levels = nuc.adopted_levels.levels[:n_levels]
levels = clean_levels(levels)

# %%
def parse_ang_mom_twoj(x):
    if len(x)==1:
        x = x[0]
    else:
        raise ValueError('Indeterminate ang mom entry: ' + str(x))
    
    p = str(x.parity)
    twoj = int(2*x.val)

#     if len(x)==2 and ( x[-1] in ['+','-'] ):
#         return [2*int(x[0]), x[-1]]
#     if len(x)==4 and ( x[-1] in ['+','-'] ):
#         return [int(x[0]), x[-1]]
#     else:
#         raise ValueError('Invalid ang mom entry: ' + str(x))
        
    return [twoj, p]

def get_J_list_from_levels(levels):
    return [parse_ang_mom_twoj(l.ang_mom) for l in levels]

def times_so_far(ls):
    out = [0]*len(ls)
    for i in range(len(ls)):
        out[i] = ls[:i+1].count(ls[i])
    return out

def append_count(jp_list):
    counts = times_so_far(jp_list)
#     ic(counts)
    for i,x in enumerate(jp_list):
        x.append(counts[i])
    return jp_list

jp_list = get_J_list_from_levels(levels)
append_count(jp_list)
# Out:
# [[3, '+', 1],
#  [5, '+', 1],
#  [7, '+', 1],
#  [1, '+', 1],
#  [9, '+', 1],
#  [3, '+', 2],
#  [5, '+', 2],
#  [1, '+', 2],
#  [7, '+', 2],
#  [5, '+', 3],
#  [11, '+', 1],
#  [5, '+', 4],
#  [3, '+', 3],
#  [7, '+', 3]]

# %% [markdown]
# # Decay extraction

# %% [markdown]
# We want to choose a Decay object from nudel and input that, and output the object containing transition information for SHMUQ

# %%
A, Z, N = 20, 10, 10
ne20 = Nuclide(20,10)
x = ne20.adopted_levels.levels[4]

# %% [markdown]
# Must be able to collect all transition information from nudel for one nuclide.

# %%
def collect_transitions(transition_type,nuc=None, nucleons=None, protons=None, n_max = 40):
    decays = []
    if not nuc:
        nuc = Nuclide(nucleons, protons)
    for level in nuc.adopted_levels.levels[:n_max]:
        decays.extend(level.decays)
    
    trans_list = []
    for decay in decays:
        print(decay.prop)
        if transition_type in decay.attr.keys():
            trans_list.append(decay)
#             print('Added to the list!')
            
    return trans_list

# %%
x = Gamma(A,Z,N,'M1')
x.Jpi = '2+'

# %%
x.fill()
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 x.fill()
#       2 x
#
# TypeError: fill() missing 5 required positional arguments: 'decay', 'twoJi', 'twoJf', 'ni', and 'nf'

# %%
trans_list = collect_transitions('BM1W',nuc=ne20)
# Out:
# {'E': '1633.602 15', 'DE': '15', 'RI': '100 ', 'DRI': '', 'M': '[E2]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BE2W': '20.3 10'}
# {'E': '2613.8 11', 'DE': '11', 'RI': '100 ', 'DRI': '', 'M': '[E2]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BE2W': '22 2'}
# {'E': '3332.54 20', 'DE': '20', 'RI': '99.4 2', 'DRI': '2', 'M': '[E1+M2+E3]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BE1W': '7.3E-6 8', 'BM2W': '0.017 4', 'BE3W': '6 2'}
# {'E': '4965.85 20', 'DE': '20', 'RI': '0.6 2', 'DRI': '2', 'M': '[M2]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BM2W': '0.0025 8'}
# {'E': '654.9 18', 'DE': '18', 'RI': '4.8 16', 'DRI': '16', 'M': '[M1]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BM1W': '2.0E-3 9'}
# ...

# %%
y = trans_list[0]
y.orig_level

# %%
az_list = [(20,10),(21,10),(22,10)]
trans = {}
for az in az_list:
    trans[az] = collect_transitions('BM1W',nucleons=az[0],protons=az[1])
# Out:
# {'E': '1633.602 15', 'DE': '15', 'RI': '100 ', 'DRI': '', 'M': '[E2]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BE2W': '20.3 10'}
# {'E': '2613.8 11', 'DE': '11', 'RI': '100 ', 'DRI': '', 'M': '[E2]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BE2W': '22 2'}
# {'E': '3332.54 20', 'DE': '20', 'RI': '99.4 2', 'DRI': '2', 'M': '[E1+M2+E3]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BE1W': '7.3E-6 8', 'BM2W': '0.017 4', 'BE3W': '6 2'}
# {'E': '4965.85 20', 'DE': '20', 'RI': '0.6 2', 'DRI': '2', 'M': '[M2]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BM2W': '0.0025 8'}
# {'E': '654.9 18', 'DE': '18', 'RI': '4.8 16', 'DRI': '16', 'M': '[M1]', 'MR': ' ', 'DMR': '', 'CC': ' ', 'DCC': '', 'TI': ' ', 'DTI': '', 'C': '', 'COIN': '', 'Q': '', 'BM1W': '2.0E-3 9'}
# ...

# %%
nl = "\n"
for az in trans.keys():
    for t in trans[az]:
        print(az)
        i = t.orig_level; f = t.dest_level
        print(t.attr,nl,i.prop,nl,"-->",nl,f.prop,nl,'-'*20)
# Out:
# (20, 10)
# {'BM1W': <2.0(9)e-3>}
#  {'E': '5621.4 17', 'DE': '17', 'J': '3-', 'T': '139 FS 35', 'DT': '35', 'L': '', 'S': '', 'DS': '', 'C': '', 'MS': '', 'Q': '', '%IT': '7 3', '%A': '93 3', 'WIDTHG': '2.4E-4 EV 6', 'ISPIN': '0', 'XREF': 'ACDF'}
#  -->
#  {'E': '4966.51 20', 'DE': '20', 'J': '2-', 'T': '3.3 PS 4', 'DT': '4', 'L': '', 'S': '', 'DS': '', 'C': '', 'MS': '', 'Q': '', 'ISPIN': '0', 'XREF': 'ABCGFI'}
#  --------------------
# (20, 10)
# {'BM1W': <6.9e-3>}
#  {'E': '7004.0 36', 'DE': '36', 'J': '4-', 'T': '305 FS 62', 'DT': '62', 'L': '', 'S': '', 'DS': '', 'C': '', 'MS': '', 'Q': '', 'ISPIN': '0', 'XREF': 'ACF'}
#  -->
#  {'E': '5621.4 17', 'DE': '17', 'J': '3-', 'T': '139 FS 35', 'DT': '35', 'L': '', 'S': '', 'DS': '', 'C': '', 'MS': '', 'Q': '', '%IT': '7 3', '%A': '93 3', 'WIDTHG': '2.4E-4 EV 6', 'ISPIN': '0', 'XREF': 'ACDF'}
#  --------------------
# (20, 10)
# {'BM1W': <1.0(3)e-4>, 'BE2W': <1.7(2)>}
# ...
